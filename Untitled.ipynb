# %%
import numpy as np
import pandas as pd
import math
import re
import inspect
import matplotlib as mp
import matplotlib.pyplot as plt
from datetime import datetime

# GameDayを日付として読み込んでしまうように修正
#df = pd.read_csv('./npb2018.csv', index_col=0, parse_dates=True)
df = pd.read_csv('./items_books_3.csv')
df
# Out:
#    _type  checkin         date ranking                                 title
# 0   dict     1544  2018年10月27日       －                            ライ麦畑で出会ったら
# 1   dict      107  2018年10月27日       －                             夜明けまで離さない
# 2   dict      258  2018年10月27日       －                                   殺る女
# 3   dict      542  2018年10月27日       －                              まぼろしの市街戦
# 4   dict      126  2018年10月27日       －                              ノーマーク爆牌党
# 5   dict      239  2018年10月27日       －                                  第三世代
# 6   dict      204  2018年10月27日       －                                   心魔師
# 7   dict      337  2018年10月27日       －                               サクらんぼの恋
# 8   dict      183  2018年10月27日       －                           13回の新月のある年に
# 9   dict      589  2018年10月27日       －                               ガンジスに還る
# 10  dict     1020  2018年10月27日       －                          嘘はフィクサーのはじまり
# ...

# %%
df = df.sort_values('ranking')

# %%
df
# Out:
#    _type  checkin         date ranking                                 title
# 21  dict     3559  2018年10月26日      12                                旅猫リポート
# 20  dict     5024  2018年10月26日      21                            search サーチ
# 19  dict      948  2018年10月26日      24                                 あいあい傘
# 18  dict     2725  2018年10月26日      29                     オズランド　笑顔の魔法おしえます。
# 11  dict      652  2018年10月27日      37  映画HUGっと！プリキュア・ふたりはプリキュア　オールスターズメモリーズ
# 17  dict     1145  2018年10月26日      74                        バーフバリ　伝説誕生　完全版
# 16  dict      441  2018年10月26日      80                                     栞
# 15  dict      222  2018年10月26日       －                                狼チャイルド
# 14  dict      402  2018年10月26日       －                                怪怪怪怪物！
# 13  dict      138  2018年10月26日       －                                恋する小説家
# 12  dict      176  2018年10月26日       －                                 黒蝶の秘密
# ...
